# %%
# Run this every time you open the spreadsheet
# %load_ext autoreload
# %autoreload 2
from collections import Counter
import lib

# in your terminal:
# cd AI4ALL2018
# git pull

# %% [markdown]
# # Load and inspect the data

# %%
# Load the data.
# Uncomment (using `ctrl+/`) one line for your choice of dataset
tweets, test_tweets = lib.read_sandy_data()
# tweets, test_tweets = lib.read_haiti_data()

# %%
# The variable "tweets" is a list of tweets.
# Mini-exercise 1: Print the number of tweets in the list
#### YOUR CODE STARTS HERE ####

print(len(tweets))

#### YOUR CODE ENDS HERE ####


# Mini-exercise 2: Assign the 11th tweet to the variable "tweet" and print it
# Hint: Remember python lists are 0 indexed! :)
#### YOUR CODE STARTS HERE ####

tweet = tweets[10] 
print(tweet)

#### YOUR CODE ENDS HERE ####


# To view the category of a tweet, we access the attribute tweet.category
# Mini-exercise 3: Print the category of this tweet.
#### YOUR CODE STARTS HERE ####

print(tweet.category)

#### YOUR CODE ENDS HERE ####
# Out:
# 1120
# what we thought could never happen : dark # streets of # manhattan due to power outage . # sandy # d @ 34th street http : //t.co/081fmhg8
# Energy

# %%
# This function prints out a table containing all the tweets, along with their category labels
lib.show_tweets(tweets)
# Out:
# <style  type="text/css" >
#     #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row0_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row0_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row0_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row1_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row1_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row1_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row2_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row2_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row2_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row3_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row3_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row3_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row4_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row4_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row4_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row5_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row5_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row5_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row6_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row6_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row6_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row7_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row7_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row7_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row8_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row8_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row8_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row9_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row9_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row9_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row10_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row10_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row10_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row11_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row11_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row11_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row12_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row12_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row12_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row13_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row13_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row13_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row14_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row14_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row14_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row15_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row15_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row15_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row16_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row16_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row16_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row17_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row17_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row17_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row18_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row18_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row18_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row19_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row19_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row19_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row20_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row20_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row20_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row21_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_a0999b0ccf21row21_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_fd03d5ca_8f02_11e9_b7e4_

# %% [markdown]
# ## Extension exercise: find the most common hashtags in the dataset

# %%
# No need to add code here! Just take a look!

hashtags = Counter()

for t in tweets:
    for idx,token in enumerate(t):
        if token=="#":
            hashtags[t[idx+1]] += 1

print(hashtags.most_common(10))
# Out:
# [('sandy', 102), ('hurricanesandy', 30), ('nyc', 11), ('frankenstorm', 7), ('sandynj', 4), ('nopower', 4), ('hurricane', 4), ('sandysucks', 3), ('sandyrelief', 3), ('scbd', 3)]

# %% [markdown]
# # Python refresher
#
# First, let's do some exercises to refresh our memory of a few Python concepts.
#
# ### Functions
# A Python function is written like this:
# ```
# def add_one(x):
#     return x+1
# ```
# The name of the function is `add_one`, `x` is the input variable, and the `return` keyword tells us what to give as output.

# %%
# Exercise 1. Define a function called "square_minus_1" that takes one variable (x), 
# squares it, subtracts 1, and returns the result.

#### YOUR CODE STARTS HERE ####

def square_minus_1(x):
    return x**2 - 1

#### YOUR CODE ENDS HERE ####

print("Testing:")
for x in [3,-4,6.5,0]:
    print(str(x), " -> ", str(square_minus_1(x)), end=' ')
    print("CORRECT" if square_minus_1(x)==(x**2-1) else "INCORRECT")
# Out:
# Testing:
# 3  ->  8 CORRECT
# -4  ->  15 CORRECT
# 6.5  ->  41.25 CORRECT
# 0  ->  -1 CORRECT

# %% [markdown]
# ### If-else statements
#
# An if/else statement looks like this:
#
# ```
# if electoral_votes >= 270:
#     print("You win the election")
# else:
#     print("You lose the election")
# ```
#
# The if-statement is evaluated (`electoral_votes >= 270`); if it's true then the code under the `if` is executed, if it's false then the code under the `else` is executed.

# %%
# Exercise 2. Define a function called "contains_ss" that takes one variable (word) 
# and returns True if the word contains a double-s and False if it doesn't.
# Hint: to test whether a string e.g. "ss" is inside another string variable e.g. word, write
#    if "ss" in word: 

#### YOUR CODE STARTS HERE ####

def contains_ss(word):
    if "ss" in word:
        return True
    else:
        return False


#### YOUR CODE ENDS HERE ####

print("Testing:")
for word in ["computer", "science", "lesson"]:
    print("{:s} ->".format(word, contains_ss(word)), end=' ')
    print("CORRECT" if contains_ss(word)==("ss" in word) else "INCORRECT")
# Out:
# Testing:
# computer -> CORRECT
# science -> CORRECT
# lesson -> CORRECT

# %% [markdown]
# ## More complex if-else statements
#
# Maybe you want to check *several* conditions? You can use an if/elif/else statement.
#
# ```
# if teamA_score > teamB_score:
#     print("Team A wins")
# elif teamA_score < teamB_score:
#     print("Team B wins")
# else:
#     print("It's a tie!")
# ```
#
# `elif` stands for "else if". In fact, the above code is just a neater way of writing this:
# ```
# if teamA_score > teamB_score:
#     print("Team A wins")
# else:
#     if teamA_score < teamB_score:
#         print("Team B wins")
#     else:
#         print("It's a tie!")
# ```
#
# You can have as many `elif` statments as you like. These are useful for when you want several options.

# %%
# Exercise 3. Define a function called "grade" that takes one input (score).
# If score >= 90, return the string "A"
# Otherwise, if score >= 80, return the string "B"
# Otherwise, if score >= 70, return the string "C"
# Otherwise, if score >= 60, return the string "D"
# Otherwise, if score >= 50, return the string "E"
# Otherwise, return the string "F"

#### YOUR CODE STARTS HERE ####

def grade(score):
    if score>=90:
        return "A"
    elif score>=80:
        return "B"
    elif score>=70:
        return "C"
    elif score>=60:
        return "D"
    elif score>=50:
        return "E"
    else:
        return "F"

#### YOUR CODE ENDS HERE ####


print("Testing:")
for (score,g) in [(77,"C"),(80,"B"),(32,"F"),(100,"A"),(69,"D")]:
    print("%d -> %s" % ((score, grade(score))), end=' ')
    print("CORRECT" if grade(score)==g else "INCORRECT")
# Out:
# Testing:
# 77 -> C CORRECT
# 80 -> B CORRECT
# 32 -> F CORRECT
# 100 -> A CORRECT
# 69 -> D CORRECT

# %% [markdown]
# # Write a rule-based tweet classifier
#
# Time to write our rule-based classifier!
# The function outline below uses a `if/elif/else` statement to return the predicted category of a tweet.
#
# Fill in the missing `if` and `elif` statements with something sensible (there is no one right answer)!
#
# Start with something simple; we'll build it into something more complicated later.

# %% [markdown]
# **TODO: Keep cell below for student**

# %%
# Hint: Search for keyword in the tweet.
# Hint: What case should your keyword have?

def classify_rb(tweet):
    
  tweet = str(tweet).lower() # this makes the tweet lower-case, so we don't have to worry about matching case

  if ________:
    return "Medical"
  elif ________:
    return "Energy"
  elif ________:
    return "Water"
  elif ________:
    return "Food"
  else:
    return "None"

# %% [markdown]
# **TODO: Below is solution cell**

# %%
# Hint: Search for keyword in the tweet.
# Hint: What case should your keyword have?

def classify_rb(tweet):
    
  tweet = str(tweet).lower() # this makes the tweet lower-case, so we don't have to worry about matching case

  if 'medical' in tweet:
    return "Medical"
  elif 'energy' in tweet:
    return "Energy"
  elif 'water' in tweet:
    return "Water"
  elif 'food' in tweet:
    return "Food"
  else:
    return "None"

# %% [markdown]
# # Test your rule-based classifier on some examples
#
# Run the cell below to see the results of your rule-based classifier.
# You should see a table showing each tweet, along with its true category and the category predicted by your system.
#
# Which types of tweets does your system get right? Which types of tweets does your system get wrong and why?
#
# How would you measure the accuracy of your system?

# %%
# python syntax: list comprehension vs for-loop
predictions = [(tweet, classify_rb(tweet)) for tweet in test_tweets] # a list of (tweet, prediction) pairs

lib.show_predictions(predictions, True)
# Out:
# <style  type="text/css" >
#     #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row0_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row0_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row0_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row1_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row1_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row1_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row2_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row2_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row2_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row3_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row3_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row3_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row4_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row4_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row4_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row5_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row5_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row5_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row6_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row6_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row6_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row7_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row7_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row7_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row8_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row8_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row8_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row9_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row9_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row9_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row10_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row10_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row10_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row11_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row11_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row11_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row12_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row12_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row12_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row13_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row13_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row13_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row14_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row14_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row14_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row15_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row15_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row15_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row16_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row16_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row16_col2 {
#             color:  blue;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row17_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row17_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row17_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row18_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row18_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row18_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row19_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row19_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row19_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row20_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row20_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row20_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row21_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0999b0ccf21row21_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_c1872eb8_8f05_11e9_b7e4_a0

# %% [markdown]
# # Break your rule-based classifier!
#
# It's time to FOOL THE RULES!
#
# You'll be deliberately trying to break each others' rule-based classifiers by writing tricky tweets that fool your neighbor's rule-based classifier
#
# Once your own classifier has been fooled by a tricky tweet, it's your job to amend the rules in your classifier to account for the new case.

# %%
def classify_rb_game(tweet):
    
    # TODO: Copy to here the body of the function classify_rb from above. When your classifer gets
    # a tweet wrong, add a new rule so it will be correct.
    #### YOUR CODE STARTS HERE ####
    
    tweet = str(tweet).lower() # this makes the tweet lower-case, so we don't have to worry about matching case

    if 'medical' in tweet:
        return "Medical"
    elif 'energy' in tweet:
        return "Energy"
    elif 'water' in tweet:
        return "Water"
    elif 'food' in tweet:
        return "Food"
    else:
        return "None"

    #### YOUR CODE ENDS HERE ####

# %% [markdown]
# ### Write a tweet about Food that will be misclassified
#
# Below, write a disaster-scenario tweet about Food that the classification function above will get wrong (i.e. fail to recognize it's about food).
#
# Hint: think of less-obvious food-related keywords that aren't included in the rule-based system above.
#
# Then run the cell - make sure the tweet is classified as something other than Food!

# %%
food_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(food_tweet)))

# %% [markdown]
# ### Write a tweet about Energy that will be misclassified

# %%
energy_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(energy_tweet)))

# %% [markdown]
# ### Write a tweet about Water that will be misclassified

# %%
water_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(water_tweet)))

# %% [markdown]
# ### Write a tweet about Medical that will be misclassified

# %%
medical_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(medical_tweet)))

# %% [markdown]
# ### Write a tweet NOT about Food, that will be falsely classified as Food
#
# Below, write a disaster-scenario tweet that is NOT about Food, but that the classifier above will classify as Food.
#
# Hint: you want to trick the classifier into thinking you're talking about food when you're not. Look at the keywords the rule-based system associates with food. Can you find a way to use them while actually talking about not-food?
#
# * For example, if the system looks for the word "food" you could write *"Waiting out #Sandy by reading Plato. Food for thought."*
# * If the system looks for the word "cook", you could write *"I hear the power's out in Cook County."*
# * More simply, you could mention food incidentally but the real subject of the tweet is something else e.g. *"Was out food shopping when I heard about the power outage on the news. Hope everyone's OK."*
#
# Then run the cell - make sure the tweet is classified as Food!

# %%
not_food_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(not_food_tweet)))

# %% [markdown]
# ### Write a tweet NOT about Energy, that will be falsely classified as Energy

# %%
not_energy_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(not_energy_tweet)))

# %% [markdown]
# ### Write a tweet NOT about Water, that will be falsely classified as Water

# %%
not_water_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(not_water_tweet)))

# %% [markdown]
# ### Write a tweet NOT about Medical, that will be falsely classified as Medical

# %%
not_medical_tweet = ""
print("This tweet is classified as: {:s}\n".format(classify_rb_game(not_medical_tweet)))

# %% [markdown]
# Bonus 1: [The Cat and Mouse Game](http://tangra.cs.yale.edu/naclo/practice/2012A.html)
#
# Bonus 2: understand the library functions! :D
# In `lib.py`:
#   * `read_sandy_data` / `read_haiti_data`
#   * `show_predictions`
#   * `show_tweets`
